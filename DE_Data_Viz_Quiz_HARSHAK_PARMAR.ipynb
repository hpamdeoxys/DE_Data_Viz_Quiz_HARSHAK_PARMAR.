# %% [markdown]
# <a href="https://colab.research.google.com/github/hpamdeoxys/DE_Data_Viz_Quiz_HARSHAK_PARMAR./blob/main/DE_Data_Viz_Quiz_HARSHAK_PARMAR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Q1. BITCOIN HOLDERS
#
# ## Which chart did you choose and why ?
# ### I selected a LINE GRAPH because it effectively displays the evolution of BITCOIN prices over time, highlighting trends across 2018 and 2019. By segmenting the data into two sets—one for each year, with each set representing the 52 weeks—the line graph clearly delineates the price trajectory during these periods.
#
#
#
#
# ## Which year seemed to be better for Bitcoin holders ?
# ### Looking at the graph we can say that the year 2019 has a better trend especially in the first 30 weeks (53 to 80)

# %%
import matplotlib.pyplot as plt
import pandas as pd

prices = [
    14292.2, 12858.9, 11467.5, 9241.1, 8559.6, 11073.5, 9704.3, 11402.3,
    8762.0, 7874.9, 8547.4, 6938.2, 6905.7, 8004.4, 8923.1, 9352.4,
    9853.5, 8459.5, 8245.1, 7361.3, 7646.6, 7515.8, 6505.8, 6167.3,
    6398.9, 6765.5, 6254.8, 7408.7, 8234.1, 7014.3, 6231.6, 6379.1,
    6734.8, 7189.6, 6184.3, 6519.0, 6729.6, 6603.9, 6593.6, 6321.7,
    6572.2, 6494.2, 6386.2, 6427.1, 5621.8, 3920.4, 4196.2, 3430.4,
    3228.7, 3964.4, 3706.8, 3785.4, 3597.2, 3677.8, 3570.9, 3502.5,
    3661.4, 3616.8, 4120.4, 3823.1, 3944.3, 4006.4, 4002.5, 4111.8,
    5046.2, 5051.8, 5290.2, 5265.9, 5830.9, 7193.0, 7262.6, 8027.4,
    8545.7, 7901.4, 8812.5, 10721.7, 11906.5, 11268.0, 11364.9, 10826.7,
    9492.1, 10815.7, 11314.5, 10218.1, 10131.0, 9594.4, 10461.1, 10337.3,
    9993.0, 8208.5, 8127.3, 8304.4, 7957.3, 9230.6, 9300.6, 8804.5,
    8497.3, 7324.1, 7546.6, 7510.9, 7080.8, 7156.2, 7321.5, 7376.8
]

prices_2018 = prices[:52]
prices_2019 = prices[52:]

weeks_2018 = range(1, 53)
weeks_2019 = range(53, 105)
df = pd.DataFrame({
    'Week_2018': weeks_2018,
    'Price_2018': prices_2018,
    'Week_2019': weeks_2019,
    'Price_2019': prices_2019
})

plt.figure(figsize=(14, 7))
plt.plot('Week_2018', 'Price_2018', data=df, marker='', color='green', linewidth=2, label="2018")
plt.plot('Week_2019', 'Price_2019', data=df, marker='', color='red', linewidth=2, label="2019")
plt.title('Bitcoin Prices in 2018 vs 2019 => HARSHAK PARMAR')
plt.xlabel('Weeks')
plt.ylabel('Price (USD)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# #Q2. CANDY
#
# ##Which chart did you choose and why ?
# ### I opted for a PIE CHART as it directly corresponds to the requirement of visualizing candy counts, effectively displaying each type's share of the total.
#
# ##What are the percentage odds that you will choose a Snickers Bar when randomly pulling out a candy out of the bag ?
# ## We can clearly see from the Pie Chart that it's 15% => 39/(260) = 0.15*100 = 15%

# %%
candy_names = ('Kit Kat', 'Snickers', 'Milky Way', 'Toblerone', 'Twix')
candy_counts = (52, 39, 78, 13, 78)

plt.pie(
    candy_counts,
    labels=candy_names,
    autopct='%1.1f%%',
)
plt.show()

# %% [markdown]
# #Q3. Dessert Popularity
#
# ## The three desserts recommended for removal, based on their lower popularity, are "Chocolate Chips," "Mousse," and "Truffles."

# %%
dessert_sales = {
    'Lava Cake': 14,
    'Mousse': 5,
    'Chocolate Cake': 12,
    'Ice Cream': 19,
    'Truffles': 6,
    'Brownie': 8,
    'Chocolate Chip Cookie': 12,
    'Chocolate Pudding': 9,
    'Souffle': 10,
    'Chocolate Cheesecake': 17,
    'Chocolate Chips': 2,
    'Fudge': 9,
    'Mochi': 13
}

sorted_desserts = sorted(dessert_sales.items(), key=lambda item: item[1])

names, sales = zip(*sorted_desserts)

fig, ax = plt.subplots()
bars = ax.bar(names, sales)

for bar in bars[:3]:
    bar.set_color('red')

plt.xlabel('Desserts')
plt.ylabel('Sales Count')
plt.title('Dessert Sales => HARSHAK PARMAR')
plt.xticks(rotation=45, ha="right")

plt.tight_layout()
plt.show()

# %% [markdown]
# #Q4. CPU
#
# ## Which chart did you choose and why ?
# ### I chose a HEATMAP because it accurately highlights the hotspots of weather conditions at specific times using color codes.
#
# ## When does the worker typically take lunch ?
# ### The worker typically takes lunch at around 13:00 (1 pm), as shown by a sudden drop in CPU utilization around that time in the Heatmap.
#
# ## Did the worker work on the weekend ?
# ### Yes, the worker did work on Sunday (6 pm to 8 pm)
#
# ##On which weekday did the worker start wokring on their computer at the latest hour ?
# ###The worker started working at 10:00 am on Wednesday, which is the latest compared to other weekdays.

# %%
cpu_usage = [
    [2, 2, 4, 2, 4, 1, 1, 4, 4, 12, 22, 23, 45, 9, 33, 56, 23, 40, 21, 6, 6, 2, 2, 3],  # Monday
    [1, 2, 3, 2, 3, 2, 3, 2, 7, 22, 45, 44, 33, 9, 23, 19, 33, 56, 12, 2, 3, 1, 2, 2],  # Tuesday
    [2, 3, 1, 2, 4, 4, 2, 2, 1, 2, 5, 31, 54, 7, 6, 34, 68, 34, 49, 6, 6, 2, 2, 3],     # Wednesday
    [1, 2, 3, 2, 4, 1, 2, 4, 1, 17, 24, 18, 41, 3, 44, 42, 12, 36, 41, 2, 2, 4, 2, 4],   # Thursday
    [4, 1, 2, 2, 3, 2, 5, 1, 2, 12, 33, 27, 43, 8, 38, 53, 29, 45, 39, 3, 1, 1, 3, 4],   # Friday
    [12, 3, 1, 2, 2, 5, 2, 8, 4, 2, 3, 1, 5, 1, 2, 3, 2, 6, 1, 2, 2, 1, 4, 3],           # Saturday
    [1, 2, 3, 1, 1, 3, 4, 2, 3, 1, 2, 2, 5, 3, 2, 1, 4, 2, 45, 26, 33, 2, 2, 1]          # Sunday
]

days = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]
hours = [str(hour) for hour in range(24)]


plt.figure(figsize=(15, 5))
sns.heatmap(cpu_usage, annot=False, fmt="d", xticklabels=hours, yticklabels=days, cmap="coolwarm")


plt.xlabel('Hour of the Day')
plt.ylabel('Day of the Week')
plt.title('Weekly CPU Usage Heatmap => HARSHAK PARMAR')


plt.tight_layout()
plt.show()

# %% [markdown]
# #Q5. Mushrooms
# ## What chart did you choose and why ?
# ### For selecting the appropriate chart type, I opted for a SCATTER PLOT due to its effectiveness in visualizing the distribution of individual data points, which aligns well with the nature of the dataset in question.
#
# ## Where are the exact x,y coordinates of the initial Mushroom ?
# ### I used the mean method to calculate the central points of x, y coordinates of the initial mushroom.
# ###X, Y = (7.700506329113924, 5.3148101265822785)

# %%
x = [
    4.61, 5.08, 5.18, 7.82, 10.46, 7.66, 7.76, 9.32, 14.04, 9.95,
    4.95, 7.23, 5.21, 8.64, 10.08, 8.32, 12.83, 7.51, 7.82, 6.29,
    0.84, 0.67, 13.16, 6.34, 0.99, 10.04, 13.06, 9.54, 11.32, 7.12,
    6.67, 10.15, 8.37, 7.62, 7.94, 10.12, 12.89, 3.55, 11.11, 9.65,
    9.42, 8.61, 0.67, 9.04, 6.49, 7.58, 8.07, 5.26, 8.28, 9.55,
    8.33, 13.70, 6.65, 2.40, 3.54, 9.19, 7.51, 0.68, 8.37, 14.82,
    5.31, 14.81, 8.75, 0.57, 5.35, 10.51, 3.11, 0.26, 5.74, 8.44,
    6.45, 13.05, 9.74, 0.40, 4.19, 14.80, 10.04, 13.47, 3.28
]

y = [
    -2.36, -3.41, 13.01, -2.91, -2.28, 12.83, 13.13, 11.94, 9.93, -2.76,
    13.31, -3.57, -2.33, 2.43, -1.83, 12.32, -0.42, -3.08, -2.98, 12.46,
    8.34, -3.19, 10.47, 12.78, 12.42, 7.29, 10.64, 11.98, 12.21, 12.52,
    5.53, 11.72, 12.91, 13.45, -2.49, 12.08, -1.09, -2.89, -1.78, 2.47,
    12.77, 12.42, 1.53, -3.23, 12.86, 13.24, 4.12, 12.10, -2.56, 12.51,
    -3.27, 7.76, 6.99, 12.59, -1.12, -1.95, 11.76, 3.62, 12.44, 12.59,
    2.92, 12.70, 0.50, 12.57, 6.39, 12.84, -2.45, 0.31, -2.57, 13.28,
    -3.46, 0.70, -2.55, -2.37, 12.48, 7.26, -2.45, 0.31, -2.51
]



plt.scatter(x, y)


center_x = sum(x) / len(x)
center_y = sum(y) / len(y)


plt.scatter(center_x, center_y, color='yellow', label='Approximate Center')


plt.legend()
plt.title('Mushroom Growth Center Approximation => HARSHAK PARMAR')
plt.xlabel('X Coordinates')
plt.ylabel('Y Coordinates')


plt.show()

(center_x, center_y)
# Out:
# (7.700506329113924, 5.3148101265822785)
